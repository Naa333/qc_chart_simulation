# %% [markdown]
# # QC Chart Simulation - Clinical Lab Values Analysis
#
# This notebook simulates quality control charts for clinical laboratory values. I'll generate random lab values within realistic ranges, calculate statistics, and visualize them with Plotly.

# %% [markdown]
# ## Step 1: Import Required Libraries

# %%
import importlib
import plot
importlib.reload(plot)
from plot import plot_graph
from load_ctrl_stats import load_stats
from generate_data import generate_data
from build_df import build_df

# %%
#load qc file
stats_df = load_stats("qc_1.xlsx")
data = generate_data(stats_df, 100)
# Build DataFrame
df = build_df(data, "02/14/2024")
# Plot graph
fig = plot_graph(df,stats_df)
fig.show()

# %%
stats_df2 = load_stats("qc_2.xlsx")
data = generate_data(stats_df2, 100)
# Build DataFrame
df = build_df(data, "03/14/2024")
# Plot graph
fig = plot_graph(df,stats_df2)
fig.show()

# %%
stats_df3 = load_stats("qc_3.xlsx")
data = generate_data(stats_df3, 100)
# Build DataFrame
df = build_df(data, "03/14/2024")
# Plot graph
fig = plot_graph(df,stats_df3)
fig.show()
